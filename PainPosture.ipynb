# %% [markdown]
# <a href="https://www.kaggle.com/code/nicholasb99/notebook99d6d4e4f9?scriptVersionId=114290296" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# Import the necessary libraries
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from scipy.stats import chi2_contingency


# CSV file
df = pd.read_csv('/kaggle/input/correlation-between-posture-personality-trait/Myers Briggs Table_S1.csv')

# To view the first few rows of data
df.head()
# Out:
#    S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0     1   53      62     125  Female            Low     0.0     0.0     0.0
# 1     2   52      69     157    Male           High     7.0     8.0     5.0
# 2     3   30      69     200    Male           High     0.0     0.0     0.0
# 3     4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4     5   45      63     199  Female       Moderate     4.0     5.0     2.0
#
#    PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 0     0.0  ESFJ  18   3  17   9   9  13  18   4       A
# 1     3.0  ISTJ   6  15  14  12  21   3  13   9       B
# 2     0.0  ESTJ  15   6  16  10  15   9  12  10       A
# 3     1.5  ISTJ   6  15  21   5  13  11  19   3       D
# 4     2.0  ENFJ  14   7  20   6   9  15  16   6       A

# %%
#  'S No' column Will be rephrased to 'ID'
df = df.rename(columns={'S No': 'ID'})

# ID TO NUMERIC
df['ID'] = df['ID'].astype(int)

# Checking for Mising values
missing = df.isnull().sum()
print(missing)

# Now, Outliers 
summary = df.describe()
print(summary)

# cSEX and POSTURE should be categorical
df['SEX'] = df['SEX'].astype('category')
df['POSTURE'] = df['POSTURE'].astype('category')

# view the first few rows of the cleaned data
df.head()
# Out:
# ID                0
# AGE               0
# HEIGHT            0
# WEIGHT            0
# SEX               0
# ACTIVITY LEVEL    0
# PAIN 1            0
# PAIN 2            0
# PAIN 3            0
# PAIN 4            0
# MBTI              0
# E                 0
# I                 0
# S                 0
# N                 0
# T                 0
# F                 0
# J                 0
# P                 0
# POSTURE           0
# dtype: int64
#               ID        AGE     HEIGHT     WEIGHT     PAIN 1     PAIN 2  \
# count  97.000000  97.000000  97.000000   97.00000  97.000000  97.000000
# mean   49.000000  43.855670  65.731959  159.43299   2.139175   3.747423
# std    28.145456  16.776093   3.737522   36.19591   2.572635   3.191071
# min     1.000000  11.000000  58.000000   68.00000   0.000000   0.000000
# 25%    25.000000  30.000000  63.000000  135.00000   0.000000   0.000000
# 50%    49.000000  45.000000  66.000000  157.00000   1.000000   3.000000
# 75%    73.000000  56.000000  68.000000  183.00000   4.000000   7.000000
# max    97.000000  82.000000  74.000000  263.00000   9.500000  10.000000
#
#           PAIN 3     PAIN 4          E          I          S          N  \
# count  97.000000  97.000000  97.000000  97.000000  97.000000  97.000000
# mean    1.943299   2.530928  12.690722   8.288660  15.134021  11.041237
# std     2.587909   3.111483   5.717956   5.697146   4.833970   4.732242
# min     0.000000   0.000000   2.000000   0.000000   5.000000   1.000000
# 25%     0.000000   0.000000   8.000000   3.000000  12.000000   7.000000
# 50%     0.500000   0.000000  13.000000   8.000000  15.000000  11.000000
# 75%     3.500000   5.000000  18.000000  13.000000  19.000000  14.000000
# max    10.000000  10.000000  21.000000  19.000000  25.000000  21.000000
#
#                T          F          J          P
# count  97.000000  97.000000  97.000000  97.000000
# mean   10.505155  13.443299  10.319588  11.680412
# std     5.332924   5.297344   5.727395   5.711003
# min     0.000000   2.000000   0.000000   2.000000
# 25%     6.000000  10.000000   5.000000   6.000000
# 50%    11.000000  13.000000  11.000000  11.000000
# 75%    14.000000  18.000000  16.000000  17.000000
# max    22.000000  24.000000  20.000000  22.000000
#    ID  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0   1   53      62     125  Female            Low     0.0     0.0     0.0
# 1   2   52      69     157    Male           High     7.0     8.0     5.0
# 2   3   30      69     200    Male           High     0.0     0.0     0.0
# 3   4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4   5   45      63     199  Female       Moderate     4.0     5.0     2.0
#
#    PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 0     0.0  ESFJ  18   3  17   9   9  13  18   4       A
# 1     3.0  ISTJ   6  15  14  12  21   3  13   9       B
# 2     0.0  ESTJ  15   6  16  10  15   9  12  10       A
# 3     1.5  ISTJ   6  15  21   5  13  11  19   3       D
# 4     2.0  ENFJ  14   7  20   6   9  15  16   6       A

# %% [markdown]
# I'm assuming these are all intended. Looks good.

# %%
# A histogram to visualize the distribution of the 'AGE' variable
plt.hist(df['AGE'])
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# %% [markdown]
# It will be important to understand the distrinbution of the age because it is often a key variable that can affect the results of the analysis

# %%
# Set up Box plot for each category of pain
sns.boxplot(x='SEX', y='PAIN 1', data=df)

plt.show()


sns.boxplot(x='SEX', y='PAIN 2', data=df)

# show the plot
plt.show()


sns.boxplot(x='SEX', y='PAIN 3', data=df)

# show the plot
plt.show()


sns.boxplot(x='SEX', y='PAIN 4', data=df)

# Print
plt.show()

# %% [markdown]
# This shows that women, based off of this sample, are more likely to experience neck and other types of pain, while men are more likely to experience thoracic and lumbar pain. This is important as it emphasizes on the importance of bearing in mind that sex may act as a significant predictor for pain in of itself.

# %%
import seaborn as sns

# Categories of pain list
pain_categories = ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']

# To what are the predictor variables
predictor_variables = ['HEIGHT', 'AGE', 'WEIGHT', 'ACTIVITY LEVEL', 'POSTURE']

# Subplot figure
fig, axs = plt.subplots(4, 5, figsize=(15, 15))

# Iteration for the pain categories
for i, pain_category in enumerate(pain_categories):
    # iterate over the predictor variables
    for j, predictor_variable in enumerate(predictor_variables):
        # create a scatterplot of the pain category and predictor variable
        sns.scatterplot(x=predictor_variable, y=pain_category, data=df, ax=axs[i, j])
        
        # add labels to the x-axis and y-axis
        axs[i, j].set_xlabel(predictor_variable)
        axs[i, j].set_ylabel(pain_category)

# show the plot
plt.show()

# %%
# Specify the predictor variables and the pain categories
predictor_variables = ['AGE', 'SEX', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']
pain_categories = ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']

# Heat map to explore correlational relationship
sns.heatmap(df[predictor_variables + pain_categories].corr(), annot=True, cmap='coolwarm')


plt.show()

# %%
predictor_variables = ['AGE', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']
pain_categories = ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']

# A df that separates the Male Category
df_male = df[df['SEX'] == 'Male']
sns.heatmap(df_male[predictor_variables + pain_categories].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap for Males')
plt.show()

# Same concept, this time for the female category 
df_female = df[df['SEX'] == 'Female']
sns.heatmap(df_female[predictor_variables + pain_categories].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap for Females')
plt.show()

# %%
predictor_variables = ['SEX', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']
pain_categories = ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']

# DF instantiation for age groups
df['AGE GROUP'] = pd.cut(df['AGE'], bins=range(0, 101, 5), right=False, labels=range(5, 101, 5))

# Making a heat map in ascending order
for age_group in sorted(df['AGE GROUP'].unique())[:-1]:  # Omit age group 80
    df_age_group = df[df['AGE GROUP'] == age_group]
    sns.heatmap(df_age_group[predictor_variables + pain_categories].corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
    plt.title(f'Correlation Heatmap for Age Group {age_group}')
    plt.show()

# %%
# Predictor Variables
predictor_variables = ['AGE', 'SEX', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']

# Itterate through pain categories
for pain_category in ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']:
    # Now predictors
    for predictor_variable in predictor_variables:
        # create a contingency table
        contingency_table = pd.crosstab(df[predictor_variable], df[pain_category])
        # perform the chi-squared test of independence
        chi2, p_value, dof, expected = chi2_contingency(contingency_table)
        # print the results
        print(f'The chi-squared test of independence between {predictor_variable} and {pain_category} is {chi2:.3f} (p-value = {p_value:.3f}).')
# Out:
# The chi-squared test of independence between AGE and PAIN 1 is 895.323 (p-value = 0.000).
# The chi-squared test of independence between SEX and PAIN 1 is 19.635 (p-value = 0.142).
# The chi-squared test of independence between POSTURE and PAIN 1 is 40.402 (p-value = 0.541).
# The chi-squared test of independence between HEIGHT and PAIN 1 is 161.662 (p-value = 0.999).
# The chi-squared test of independence between WEIGHT and PAIN 1 is 740.815 (p-value = 0.647).
# The chi-squared test of independence between ACTIVITY LEVEL and PAIN 1 is 16.266 (p-value = 0.962).
# The chi-squared test of independence between AGE and PAIN 2 is 1007.471 (p-value = 0.000).
# The chi-squared test of independence between SEX and PAIN 2 is 13.697 (p-value = 0.621).
# The chi-squared test of independence between POSTURE and PAIN 2 is 51.785 (p-value = 0.328).
# The chi-squared test of independence between HEIGHT and PAIN 2 is 237.802 (p-value = 0.787).
# The chi-squared test of independence between WEIGHT and PAIN 2 is 820.286 (p-value = 0.854).
# The chi-squared test of independence between ACTIVITY LEVEL and PAIN 2 is 29.230 (p-value = 0.607).
# The chi-squared test of independence between AGE and PAIN 3 is 903.597 (p-value = 0.000).
# The chi-squared test of independence between SEX and PAIN 3 is 21.530 (p-value = 0.089).
# The chi-squared test of independence between POSTURE and PAIN 3 is 31.501 (p-value = 0.882).
# The chi-squared test of independence between HEIGHT and PAIN 3 is 196.459 (p-value = 0.908).
# The chi-squared test of independence between WEIGHT and PAIN 3 is 800.682 (p-value = 0.126).
# The chi-squared test of independence between ACTIVITY LEVEL and PAIN 3 is 21.464 (p-value = 0.805).
# The chi-squared test of independence between AGE and PAIN 4 is 886.365 (p-value = 0.093).
# The chi-squared test of independence between SEX and PAIN 4 is 15.575 (p-value = 0.483).
# The chi-squared test of independence between POSTURE and PAIN 4 is 42.357 (p-value = 0.702).
# The chi-squared test of independence between HEIGHT and PAIN 4 is 197.505 (p-value = 0.997).
# The chi-squared test of independence between WEIGHT and PAIN 4 is 988.036 (p-value = 0.002).
# The chi-squared test of independence between ACTIVITY LEVEL and PAIN 4 is 23.829 (p-value = 0.851).

# %% [markdown]
# Judging this output, it is apparent that:
#
# 1) Activity Level is better at predicting neck pain.
# 2) Posture is a better predictor for thoracic pain.
# 3) Age is the better predictor for lumbar pain
# 4) weight is the better predictor for other types of pain.
#
# I would suggest adding more sample data and more columns of data such as health history, country, and line of work. Furthermore, from the plots above, it was deduced that sex (Male, Female) may play a significant role in how pain is experienced. Thus, this same test to render p-values will be conducted for all pain categories where men and women are instantiated as separate data frames.

# %%
# List of variable predictions
predictor_variables = ['AGE', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']


for pain_category in ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']:
  
    df_male = df[df['SEX'] == 'Male']
    
    # Continue itteration 
    if df_male.shape[0] > 0:
        # Predictor variable itteration
        for predictor_variable in predictor_variables:
            # To Calculate the chi-squared test for male subjects
            male_ctab, male_p_value, male_dof, male_expected = chi2_contingency(pd.crosstab(df_male[predictor_variable], df_male[pain_category]))

            # To print the results for male subjects
            print(f'For male subjects, the chi-squared test between {predictor_variable} and {pain_category} gives a p-value of {male_p_value:.3f}.')
    
    # Here, Create a dataframe for female subjects
    df_female = df[df['SEX'] == 'Female']
    
    # Shape of df
    if df_female.shape[0] > 0:
        # loop through each predictor variable
        for predictor_variable in predictor_variables:
            # chi square
            female_ctab, female_p_value, female_dof, female_expected = chi2_contingency(pd.crosstab(df_female[predictor_variable], df_female[pain_category]))

            # print for female
            print(f'For female subjects, the chi-squared test between {predictor_variable} and {pain_category} gives a p-value of {female_p_value:.3f}.')
# Out:
# For male subjects, the chi-squared test between AGE and PAIN 1 gives a p-value of 0.816.
# For male subjects, the chi-squared test between POSTURE and PAIN 1 gives a p-value of 0.485.
# For male subjects, the chi-squared test between HEIGHT and PAIN 1 gives a p-value of 0.845.
# For male subjects, the chi-squared test between WEIGHT and PAIN 1 gives a p-value of 0.125.
# For male subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 1 gives a p-value of 0.798.
# For female subjects, the chi-squared test between AGE and PAIN 1 gives a p-value of 0.039.
# For female subjects, the chi-squared test between POSTURE and PAIN 1 gives a p-value of 0.259.
# For female subjects, the chi-squared test between HEIGHT and PAIN 1 gives a p-value of 0.809.
# For female subjects, the chi-squared test between WEIGHT and PAIN 1 gives a p-value of 0.484.
# For female subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 1 gives a p-value of 0.861.
# For male subjects, the chi-squared test between AGE and PAIN 2 gives a p-value of 0.265.
# For male subjects, the chi-squared test between POSTURE and PAIN 2 gives a p-value of 0.259.
# For male subjects, the chi-squared test between HEIGHT and PAIN 2 gives a p-value of 0.660.
# For male subjects, the chi-squared test between WEIGHT and PAIN 2 gives a p-value of 0.736.
# For male subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 2 gives a p-value of 0.474.
# For female subjects, the chi-squared test between AGE and PAIN 2 gives a p-value of 0.025.
# For female subjects, the chi-squared test between POSTURE and PAIN 2 gives a p-value of 0.719.
# For female subjects, the chi-squared test between HEIGHT and PAIN 2 gives a p-value of 0.844.
# For female subjects, the chi-squared test between WEIGHT and PAIN 2 gives a p-value of 0.812.
# For female subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 2 gives a p-value of 0.580.
# For male subjects, the chi-squared test between AGE and PAIN 3 gives a p-value of 0.131.
# For male subjects, the chi-squared test between POSTURE and PAIN 3 gives a p-value of 0.524.
# For male subjects, the chi-squared test between HEIGHT and PAIN 3 gives a p-value of 0.853.
# For male subjects, the chi-squared test between WEIGHT and PAIN 3 gives a p-value of 0.097.
# For male subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 3 gives a p-value of 0.887.
# For female subjects, the chi-squared test between AGE and PAIN 3 gives a p-value of 0.154.
# For female subjects, the chi-squared test between POSTURE and PAIN 3 gives a p-value of 0.922.
# For female subjects, the chi-squared test between HEIGHT and PAIN 3 gives a p-value of 0.539.
# For female subjects, the chi-squared test between WEIGHT and PAIN 3 gives a p-value of 0.487.
# For female subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 3 gives a p-value of 0.685.
# For male subjects, the chi-squared test between AGE and PAIN 4 gives a p-value of 0.530.
# For male subjects, the chi-squared test between POSTURE and PAIN 4 gives a p-value of 0.541.
# For male subjects, the chi-squared test between HEIGHT and PAIN 4 gives a p-value of 0.916.
# For male subjects, the chi-squared test between WEIGHT and PAIN 4 gives a p-value of 0.010.
# For male subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 4 gives a p-value of 0.938.
# For female subjects, the chi-squared test between AGE and PAIN 4 gives a p-value of 0.338.
# For female subjects, the chi-squared test between POSTURE and PAIN 4 gives a p-value of 0.427.
# For female subjects, the chi-squared test between HEIGHT and PAIN 4 gives a p-value of 0.610.
# For female subjects, the chi-squared test between WEIGHT and PAIN 4 gives a p-value of 0.022.
# For female subjects, the chi-squared test between ACTIVITY LEVEL and PAIN 4 gives a p-value of 0.444.

# %%
# List of predictor variables
predictor_variables = ['AGE', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']

# Pain category loop
for pain_category in ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']:
    # create a dataframe for female subjects
    df_female = df[df['SEX'] == 'Female']
    
    # df check
    if df_female.shape[0] > 0:
        # loop through each predictor variable
        for predictor_variable in predictor_variables:
            # Crosstab
            female_ctab = pd.crosstab(df_female[predictor_variable], df_female[pain_category])
            
            # Heatmap generation
            sns.heatmap(female_ctab, annot=True, fmt='d')
            plt.title(f'Heatmap for Female Subjects: {pain_category}')
            plt.xlabel(pain_category)
            plt.ylabel(predictor_variable)
            plt.show()

# %% [markdown]
# To wrap this up, from the beginning we saw a variation between types of pain experienced by men and women. So here are Heatmaps that shows various relationships between the category of Pain and the predictor variables (AGE, WEIGHT, HEIGHT, POSTURE), now separated by SEX. In the next cell, the Male SEX will then be discerned.

# %%
# List of predictor variables
predictor_variables = ['AGE', 'POSTURE', 'HEIGHT', 'WEIGHT', 'ACTIVITY LEVEL']

# loop 
for pain_category in ['PAIN 1', 'PAIN 2', 'PAIN 3', 'PAIN 4']:
    # male df
    df_female = df[df['SEX'] == 'Male']
    
    # check df
    if df_female.shape[0] > 0:
        # loop through each predictor variable
        for predictor_variable in predictor_variables:
            # Cross tab
            female_ctab = pd.crosstab(df_female[predictor_variable], df_female[pain_category])
            
            # Heatmap using the crosstab data
            sns.heatmap(female_ctab, annot=True, fmt='d')
            plt.title(f'Heatmap for Male Subjects: {pain_category}')
            plt.xlabel(pain_category)
            plt.ylabel(predictor_variable)
            plt.show()

# %% [markdown]
# Analysis to be continued via analytical summaries and perhaps more visualizations of more relationships. Based on the correlation matrices and various statistical summaries, I would strongly advise the data producer to compile more samples and more neccessary variables to mitigate ambiguities. As shown, the correlation matrices based on AGE and SEX can introduce ambiguities towards statistical hypotheses.
